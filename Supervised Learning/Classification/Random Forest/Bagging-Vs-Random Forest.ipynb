# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.tree import plot_tree

# %%
X,y = make_classification(n_features=5, n_redundant=0, n_informative=5, n_clusters_per_class=1)

# %%
df = pd.DataFrame(X, columns=['col1', 'col2', 'col3', 'col4', 'col5'])
df['target'] = y

# %%
df.head()
# Out:
#        col1      col2      col3      col4      col5  target
# 0 -0.714157 -0.679104 -1.246677  0.884098 -1.045549       1
# 1  0.713596 -1.002871  2.532107  0.730373  3.048068       0
# 2 -1.577074 -2.069570 -1.256449  1.816886  4.288244       0
# 3 -1.704332 -1.399827 -3.025379  2.229377 -1.944162       1
# 4 -0.616433 -1.992517 -1.181183  1.922790 -1.199408       1

# %% [markdown]
# # **For Bagging Classifier**

# %%
bag = BaggingClassifier(max_features=2)

# %%
bag.fit(df.iloc[:, 0:5], df.iloc[:, -1])
# Out:
# BaggingClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(bag.estimators_[0])
plt.show()

# %% [markdown]
# # **For Random Forest Classifier**

# %%
clf = RandomForestClassifier(max_features=2)

# %%
clf.fit(df.iloc[:, 0:5], df.iloc[:, -1])
# Out:
# RandomForestClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(clf.estimators_[4])
plt.show()
